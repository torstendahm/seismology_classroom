# %% [markdown]
# # Data Read-In
#
# ## Introduction
#
# We have checked in the previous submodule about Numpy and Pandas and how to read data using them. This appendix shows other ways of reading data, such as an individual read-in and also two other libraries.
#
# Table of contents:
#
# * [Individual Read-in](#Individual-Read-in)
# * [JSON](#JSON)
# * [GEOJSON](#GEOJSON-for-geo-data)

# %% [markdown]
# ## Individual Read-in
#
# Python has a built-in function called `open()`. This function simply returns a file object.

# %%
file = 'data/ingv_seismic.csv'

with open(file, 'r') as f:
    attribute1 = []
    filedict = {}
    for ii, line in enumerate(f):
        # line.strip
        line = line.replace('\n', '')
        line = line.replace('\"', '')
        line = line.rsplit(';')
        
        if ii < 4:
            print(ii, line)
        
        if ii == 0:
            header = line
            continue
        
        attribute1.append(line[0])
        
        for nn in range(len(header)):
            if header[nn] not in filedict:
                filedict[header[nn]] = []
            filedict[header[nn]].append(line[nn])

print()
print(header)
print()
print(attribute1) 
print()
print(filedict)
# Out:
# 0 ['Station', 'Net', 'Municipality', 'Lat (N)', 'Lon (E)', 'Elev (m)', 'EC8/NTC topographic category', 'NTC08 soil category', 'NTC18 soil category', 'Reference']
# 1 ['ACATE', 'IV', 'Acate', '37.0239', '14.5006', '210', 'T1', 'A*', 'missing', 'none']
# 2 ['ACER', 'IV', 'Acerenza', '40.7867', '15.9427', '690', 'T2*', 'B*', 'missing', 'none']
# 3 ['ACOM', 'OX', 'Acomizza', '46.5479', '13.5149', '1715', 'T3*', 'A*', 'missing', 'none']
#
# ['Station', 'Net', 'Municipality', 'Lat (N)', 'Lon (E)', 'Elev (m)', 'EC8/NTC topographic category', 'NTC08 soil category', 'NTC18 soil category', 'Reference']
#
# ['ACATE', 'ACER', 'ACOM', 'ACQ', 'AGOR', 'ALB1', 'AM01', 'AM02', 'AM03', 'AM04', 'AM05', 'AMAL', 'AMRC', 'AMUR', 'AND3', 'APEC', 'APRC', 'AQU', 'ARCI', 'ASOL', 'ASQU', 'ATBU', 'ATCC', 'ATFO', 'ATLO', 'ATPC', 'ATPI', 'ATTE', 'ATVO', 'AVG3', 'AVL', 'BAD', 'BAG8', 'BALD', 'BARO', 'BDI', 'BEL3', 'BENI', 'BHB', 'BIOG', 'BNI', 'BNO', 'BOB', 'BOO', 'BORM', 'BOTM', 'BOTT', 'BOZZ', 'BRIS', 'BRSN', 'BSC3', 'BSSO', 'BULG', 'BURY', 'CADA', 'CADC', 'CAFE', 'CAFI', 'CAPA', 'CAPR', 'CAR1', 'CARE', 'CDCA', 'CEL', 'CELI', 'CERA', 'CESI', 'CGG3', 'CGRP', 'CIMA', 'CIMO', 'CLT3', 'CLUD', 'CMP3', 'CMPO', 'CNCS', 'COL3', 'COR1', 'CPGN', 'CRM1', 'CRMI', 'CRND', 'CROCE', 'CRTC', 'CSG3', 'CSO1', 'CTL8', 'CUC', 'DANT', 'DOSS', 'DRE', 'ECHR', 'EMCN', 'ENIC', 'EPIT', 'EPOZ', 'EUCT', 'EVRN', 'FAEN', 'FANO', 'FAVR', 'FAZ', 'FCOR', 'FDS', 'FEMA', 'FERC', 'FERS', 'FIAM', 'FIE', 'FIR', 'FIU1', 'FIVI', 'FOPC', 'FOSD', 'FOSV', 'FRE8', 'FREG', 'FUSE', 'GAG1', 'GAGG', 'GALF', 'GATE', 'GAVE', 'GDFR', 'GEA', 'GLNS', 'GNU', 'GNV', 'GRIS', 'GUAR', 'GUMA', 'HLNI', 'HMDC', 'HVZN', 'IACL', 'IBCM', 'ILLI', 'ILOS', 'IMOL', 'INTR', 'ISPIC', 'IVPL', 'JOPP', 'LAV9', 'LEC', 'LEOD', 'LGS3', 'LIO3', 'LNSS', 'LNT', 'LPEL', 'LRNO', 'LTRZ', 'MAON', 'MARN', 'MBAL', 'MBFT', 'MCEL', 'MCIF', 'MCLF', 'MDAR', 'MDI', 'MELA', 'MERA', 'MESG', 'MGAB', 'MGR', 'MGRO', 'MIDA', 'MILN', 'MIR07', 'MLCO', 'MLN', 'MML1', 'MMO1', 'MMP1', 'MMUR', 'MNS', 'MNT3', 'MNTP', 'MNTV', 'MOCO', 'MODE', 'MOMA', 'MPAG', 'MPAZ', 'MPRI', 'MRB1', 'MRLC', 'MRN3', 'MRNE', 'MSAG', 'MSRU', 'MTCL', 'MTFT', 'MTL1', 'MTMR', 'MTRA', 'MTRZ', 'MURB', 'NAPI', 'NDIM', 'NEG8', 'NEVI', 'NOV', 'NRCA', 'NSC3', 'OPI', 'OPPE', 'ORP', 'ORZI', 'OSSC', 'OZOL', 'PANI', 'PAOL', 'PCN', 'PCRO', 'PGN3', 'PIEI', 'PIGN', 'PIO1', 'PIPA', 'PLAC', 'PLRO', 'PLTA', 'PNAL', 'POFI', 'PP3', 'PPL1', 'PRED', 'PSB1', 'PST3', 'PTRJ', 'PZUN', 'RCU', 'RDM3', 'REMY', 'RM33', 'RMMM', 'RMVT', 'RNI2', 'ROM9', 'RONC', 'ROVR', 'RRL', 'RSF3', 'RSP', 'SABO', 'SACR', 'SACS', 'SAIV', 'SALB', 'SALI', 'SALO', 'SANR', 'SARZ', 'SATI', 'SBPO', 'SCIAR', 'SCL3', 'SEF1', 'SELL', 'SENI', 'SERM', 'SERS', 'SFI', 'SFL3', 'SGAL', 'SGG', 'SGO', 'SGSC', 'SGTA', 'SIRI', 'SLC1', 'SLCN', 'SNAL', 'SNR3', 'SNS1', 'SNTG', 'SRN3', 'SSB3', 'SSFR', 'SSM1', 'SSY', 'STAL', 'STN3', 'SULA', 'SULC', 'SULP', 'T0104', 'T0701', 'T0721', 'T0724', 'T0819', 'T0821', 'T0911', 'T0912', 'T1011', 'T1012', 'T1101', 'T1201', 'T1211', 'T1212', 'T1213', 'T1214', 'T1215', 'T1216', 'T1217', 'T1218', 'T1219', 'T1220', 'T1221', 'T1222', 'T1241', 'T1242', 'T1243', 'T1244', 'T1245', 'T1256', 'T1299', 'T1361', 'T1363', 'T1365', 'T1366', 'T1411', 'T1412', 'T1413', 'T1414', 'T1415', 'T1573', 'T1574', 'T1581', 'T1582', 'TEGI', 'TERO', 'TIP', 'TRE1', 'TREG', 'TREM', 'TRIV', 'TRN1', 'TUE', 'UMBT', 'VAGA', 'VALS', 'VARA', 'VARN', 'VDP3', 'VDS3', 'VENL', 'VGG3', 'VITU', 'VLC', 'VNF1', 'VOBA', 'VOLT', 'VRB', 'VULT', 'VVLD', 'WDD', 'ZCCA', 'ZEN8', 'ZIAN', 'ZONE', 'ZOU2', 'ZOVE']
#
# {'Station': ['ACATE', 'ACER', 'ACOM', 'ACQ', 'AGOR', 'ALB1', 'AM01', 'AM02', 'AM03', 'AM04', 'AM05', 'AMAL', 'AMRC', 'AMUR', 'AND3', 'APEC', 'APRC', 'AQU', 'ARCI', 'ASOL', 'ASQU', 'ATBU', 'ATCC', 'ATFO', 'ATLO', 'ATPC', 'ATPI', 'ATTE', 'ATVO', 'AVG3', 'AVL', 'BAD', 'BAG8', 'BALD', 'BARO', 'BDI', 'BEL3', 'BENI', 'BHB', 'BIOG', 'BNI', 'BNO', 'BOB', 'BOO', 'BORM', 'BOTM', 'BOTT', 'BOZZ', 'BRIS', 'BRSN', 'BSC3', 'BSSO', 'BULG', 'BURY', 'CADA', 'CADC', 'CAFE', 'CAFI', 'CAPA', 'CAPR', 'CAR1', 'CARE', 'CDCA', 'CEL', 'CELI', 'CERA', 'CESI', 'CGG3', 'CGRP', 'CIMA', 'CIMO', 'CLT3', 'CLUD', 'CMP3', 'CMPO', 'CNCS', 'COL3', 'COR1', 'CPGN', 'CRM1', 'CRMI', 'CRND', 'CROCE', 'CRTC', 'CSG3', 'CSO1', 'CTL8', 'CUC', 'DANT', 'DOSS', 'DRE', 'ECHR', 'EMCN', 'ENIC', 'EPIT', 'EPOZ', 'EUCT', 'EVRN', 'FAEN', 'FANO', 'FAVR', 'FAZ', 'FCOR', 'FDS', 'FEMA', 'FERC', 'FERS', 'FIAM', 'FIE', 'FIR', 'FIU1', 'FIVI', 'FOPC', 'FOSD', 'FOSV', 'FRE8', 'FREG', 'FUSE', 'GAG1', 'GAGG', 'GALF', 'GATE', 'GAVE', 'GDFR', 'GEA', 'GLNS', 'GNU', 'GNV', 'GRIS', 'GUAR', 'GUMA', 'HLNI', 'HMDC', 'HVZN', 'IACL', 'IBCM', 'ILLI', 'ILOS', 'IMOL', 'INTR', 'ISPIC', 'IVPL', 'JOPP', 'LAV9', 'LEC', 'LEOD', 'LGS3', 'LIO3', 'LNSS', 'LNT', 'LPEL', 'LRNO', 'LTRZ', 'MAON', 'MARN', 'MBAL', 'MBFT', 'MCEL', 'MCIF', 'MCLF', 'MDAR', 'MDI', 'MELA', 'MERA', 'MESG', 'MGAB', 'MGR', 'MGRO', 'MIDA', 'MILN', 'MIR07', 'MLCO', 'MLN', 'MML1', 'MMO1', 'MMP1', 'MMUR', 'MNS', 'MNT3', 'MNTP', 'MNTV', 'MOCO', 'MODE', 'MOMA', 'MPAG', 'MPAZ', 'MPRI', 'MRB1', 'MRLC', 'MRN3', 'MRNE', 'MSAG', 'MSRU', 'MTCL', 'MTFT', 'MTL1', 'MTMR', 'MTRA', 'MTRZ', 'MURB', 'NAPI', 'NDIM', 'NEG8', 'NEVI', 'NOV', 'NRCA', 'NSC3', 'OPI', 'OPPE', 'ORP', 'ORZI', 'OSSC', 'OZOL', 'PANI', 'PAOL', 'PCN', 'PCRO', 'PGN3', 'PIEI', 'PIGN', 'PIO1', 'PIPA', 'PLAC', 'PLRO', 'PLTA', 'PNAL', 'POFI', 'PP3', 'PPL1', 'PRED', 'PSB1', 'PST3', 'PTRJ', 'PZUN', 'RCU', 'RDM3', 'REMY', 'RM33', 'RMMM', 'RMVT', 'RNI2', 'ROM9', 'RONC', 'ROVR', 'RRL', 'RSF3', 'RSP', 'SABO', 'SACR', 'SACS', 'SAIV', 'SALB', 'SALI', 'SALO', 'SANR', 'SARZ', 'SATI', 'SBPO', 'SCIAR', 'SCL3', 'SEF1', 'SELL', 'SENI', 'SERM', 'SERS', 'SFI', 'SFL3', 'SGAL', 'SGG', 'SGO', 'SGSC', 'SGTA', 'SIRI', 'SLC1', 'SLCN', 'SNAL', 'SNR3', 'SNS1', 'SNTG', 'SRN3', 'SSB3', 'SSFR', 'SSM1', 'SSY', 'STAL', 'STN3', 'SULA', 'SULC', 'SULP', 'T0104', 'T0701', 'T0721', 'T0724', 'T0819', 'T0821', 'T0911', 'T0912', 'T1011', 'T1012', 'T1101', 'T1201', 'T1211', 'T1212', 'T1213', 'T1214', 'T1215', 'T1216', 'T1217', 'T1218', 'T1219', 'T1220', 'T1221', 'T1222', 'T1241', 'T1242', 'T1243', 'T1244', 'T1245', 'T1256', 'T1299', 'T1361', 'T1363', 'T1365', 'T1366', 'T1411', 'T1412', 'T1413', 'T1414', 'T1415', 'T1573', 'T1574', 'T1581', 'T1582', 'TEGI', 'TERO', 'TIP', 'TRE1', 'TREG', 'TREM', 'TRIV', 'TRN1', 'TUE', 'UMBT', 'VAGA', 'VALS', 'VARA', 'VARN', 'VDP3', 'VDS3', 'VENL', 'VGG3', 'VITU', 'VLC', 'VNF1', 'VOBA', 'VOLT', 'VRB', 'VULT', 'VVLD', 'WDD', 'ZCCA', 'ZEN8', 'ZIAN', 'ZONE', 'ZOU2', 'ZOVE'], 'Net': ['IV', 'IV', 'OX', 'IT', 'OX', 'XK', 'XO', 'XO', 'XO', 'XO', 'XO', 'ST', 'ST', 'IV', 'IX', 'IV', 'IV', 'MN', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IX', 'IT', 'OX', 'IV', 'OX', 'IV', 'IV', 'IX', 'IX', 'GU', 'IV', 'MN', 'IT', 'IV', 'OX', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IX', 'IV', 'IV', 'GU', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'ST', 'IV', 'MN', 'IV', 'IV', 'IV', 'IX', 'OX', 'IV', 'OX', 'IX', 'OX', 'IX', 'IV', 'IV', 'IX', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IX', 'IT', 'IV', 'MN', 'IT', 'ST', 'OX', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IT', 'IV', 'IT', 'IV', 'IV', 'IV', 'IV', 'IT', 'IV', 'IV', 'GU', 'IT', 'GU', 'IV', 'IV', 'IV', 'OX', 'IV', 'ST', 'IV', 'IV', 'IV', 'IT', 'IT', 'IT', 'IT', 'IT', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IT', 'IV', 'IX', 'IX', 'IV', 'IT', 'IV', 'IT', 'IV', 'IV', 'OX', 'IV', 'IV', 'IV', 'IV', 'IT', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'IV', 'GU', 'IV', 'IV', 'IV', 'IV', 'OX', 'IV',  ...

# %% [markdown]
# ## Individual Write-out

# %%
f = open("data/test_out.txt", "w")
f.write("Stations in Italy\n")
for idx in range(len(filedict['Station'])):
    d = filedict
    f.write('The station %s.%s is located at %s, %s.\n'
            % (d['Station'][idx], d['Net'][idx], d['Lat (N)'][idx], d['Lon (E)'][idx]))
f.close()

# %% [markdown]
# ## JSON
#
# JSON is a JavaScript Object Notation. Python supports JSON with the built-in package **`json`**.

# %%
import json

file = 'data/finite_fault_usgs.json'
file = 'data/metadata.json'

with open(file, 'r') as f:
  data = json.load(f)

print(data)
# Out:
# {'details': {'status': 200, 'url': 'https://strongmotioncenter.org/wserv/records/query?eventid=NC72282711&minepidist=0.0&maxepidist=37.5&orderby=epidist-asc&rettype=dataset&download=P&email=luklehma@uni-potsdam.de&groupby=station&nodata=404'}, 'count': 88, 'results': {'stations': [{'code': 'BRIB', 'network': 'BK', 'status': 'Active', 'channels': None, 'recorder_type': None, 'numRecorders': None, 'name': 'Briones Reserve', 'location': None, 'longitude': -122.15269, 'latitude': 37.91932, 'elevation': '237', 'type': 'Ground', 'Vs30': None, 'siteclass': None, 'events': [{'id': 'NC72282711', 'cesmd_id': 'SouthNapa_24Aug2014_72282711', 'mag': 6, 'longitude': -122.313, 'latitude': 38.22, 'depth': 11.3, 'place': '8.0 km (5.0 mi) SSW of Napa, CA ', 'time': '2014-08-24 10:20:44', 'state': 'CA', 'country': 'US', 'detail': '6.0MW, 03:20:44 PDT, 38.22N 122.31W Depth 11.3 km', 'net': 'NC', 'magType': 'MW', 'faultType': 'SS', 'type': 'earthquake', 'title': 'South Napa Earthquake of 24 Aug 2014', 'record': {'epidist': 36.3, 'pgav1': 0.011, 'pgav2': 0.011, 'pga_str': None, 'pgv': 1.39, 'pgd': 0.8, 'sa03': 0.02, 'sa10': 0.03, 'sa30': 0.002, 'fault_dist': 36.3, 'data_availability': {'plot': 'true', 'processed': 'true', 'raw': 'true'}}}]}, {'code': 'RFSB', 'network': 'BK', 'status': 'Active', 'channels': None, 'recorder_type': None, 'numRecorders': None, 'name': 'Richmond Field Station, Richmond, CA, US', 'location': None, 'longitude': -122.33607, 'latitude': 37.91608, 'elevation': '-26', 'type': 'Ground', 'Vs30': None, 'siteclass': None, 'events': [{'id': 'NC72282711', 'cesmd_id': 'SouthNapa_24Aug2014_72282711', 'mag': 6, 'longitude': -122.313, 'latitude': 38.22, 'depth': 11.3, 'place': '8.0 km (5.0 mi) SSW of Napa, CA ', 'time': '2014-08-24 10:20:44', 'state': 'CA', 'country': 'US', 'detail': '6.0MW, 03:20:44 PDT, 38.22N 122.31W Depth 11.3 km', 'net': 'NC', 'magType': 'MW', 'faultType': 'SS', 'type': 'earthquake', 'title': 'South Napa Earthquake of 24 Aug 2014', 'record': {'epidist': 33.8, 'pgav1': 0.027, 'pgav2': 0.027, 'pga_str': None, 'pgv': 2.21, 'pgd': 0.6, 'sa03': 0.058, 'sa10': 0.021, 'sa30': 0.002, 'fault_dist': 33.9, 'data_availability': {'plot': 'true', 'processed': 'true', 'raw': 'true'}}}]}, {'code': '58183', 'network': 'CE', 'status': 'Active', 'channels': 9, 'recorder_type': 'L', 'numRecorders': 3, 'name': 'Briones Reservoir - Briones Dam', 'location': 'Briones Dam', 'longitude': -122.2092, 'latitude': 37.9135, 'elevation': '189', 'type': 'Dam', 'Vs30': None, 'siteclass': None, 'events': [{'id': 'NC72282711', 'cesmd_id': 'SouthNapa_24Aug2014_72282711', 'mag': 6, 'longitude': -122.313, 'latitude': 38.22, 'depth': 11.3, 'place': '8.0 km (5.0 mi) SSW of Napa, CA ', 'time': '2014-08-24 10:20:44', 'state': 'CA', 'country': 'US', 'detail': '6.0MW, 03:20:44 PDT, 38.22N 122.31W Depth 11.3 km', 'net': 'NC', 'magType': 'MW', 'faultType': 'SS', 'type': 'earthquake', 'title': 'South Napa Earthquake of 24 Aug 2014', 'record': {'epidist': 35.2, 'pgav1': 0.021, 'pgav2': 0.021, 'pga_str': 0.039, 'pgv': 1.62, 'pgd': 0.5, 'sa03': 0.051, 'sa10': 0.031, 'sa30': 0.006, 'fault_dist': 35.3, 'data_availability': {'plot': 'true', 'processed': 'true', 'raw': 'true'}}}]}, {'code': '58267', 'network': 'CE', 'status': 'Active', 'channels': 6, 'recorder_type': 'K', 'numRecorders': 1, 'name': 'San Rafael - Richmond Brdg Geotech Array', 'location': 'SanRafael-Aray', 'longitude': -122.4808, 'latitude': 37.9427, 'elevation': '3', 'type': 'Array', 'Vs30': 921, 'siteclass': 'B', 'events': [{'id': 'NC72282711', 'cesmd_id': 'SouthNapa_24Aug2014_72282711', 'mag': 6, 'longitude': -122.313, 'latitude': 38.22, 'depth': 11.3, 'place': '8.0 km (5.0 mi) SSW of Napa, CA ', 'time': '2014-08-24 10:20:44', 'state': 'CA', 'country': 'US', 'detail': '6.0MW, 03:20:44 PDT, 38.22N 122.31W Depth 11.3 km', 'net': 'NC', 'magType': 'MW', 'faultType': 'SS', 'type': 'earthquake', 'title': 'South Napa Earthquake of 24 Aug 2014', 'record': {'epidist': 34.1, 'pgav1': 0.009, 'pgav2': 0.007, 'p ...

# %% [markdown]
# ## GEOJSON for geo data

# %%
import geojson

file = 'data/germany.geojson' # from shakygrounds2

with open(file, 'r') as f:
  data = geojson.load(f)

#print(data)
print(data['features'])
# shape files etc.
# e.g. line, polygon objects
# Out:
# [{"geometry": {"coordinates": [[[5.852162781451399, 50.88404790979752], [5.794128831258057, 50.916369651612555], [5.781476726326511, 50.92426477217214], [5.769671135368808, 50.933377220250925], [5.758828754651356, 50.94361692084357], [5.749056759270534, 50.954882656244614], [5.740451743745023, 50.967063066568365], [5.733098767195354, 50.980037750522484], [5.727070512548915, 50.99367845555437], [5.722426568081523, 51.0078503456059], [5.719212838397421, 51.022413333945074], [5.717461090670036, 51.03722346789952], [5.717188640628859, 51.05213435180438], [5.718398181396385, 51.06699859409859], [5.721077756867056, 51.08166926426549], [5.725200879891347, 51.09600134521614], [5.730726794096734, 51.10985316675859], [5.737600876757549, 51.12308780598379], [5.745755178731359, 51.13557444072536], [5.755109096124725, 51.14718964271444], [5.765570167049041, 51.15781859764734], [5.777034985590625, 51.1673562401054], [5.789390223960667, 51.175708292108865], [5.802513752721214, 51.182792195038765], [5.816275848013972, 51.18853792571486], [5.923040970001803, 51.22699955515297], [5.922688349856085, 51.22957418616441], [5.922149594263414, 51.244598644108514], [5.923117515417904, 51.25960156791494], [5.925582390031287, 51.27443224514975], [5.929519457113162, 51.28894169368839], [5.934889166708457, 51.302984158321244], [5.941637577197984, 51.31641857494303], [5.949696897170999, 51.32910998761756], [5.958986166426362, 51.34093090428269], [5.969412069261276, 51.351762577476606], [5.980869871877676, 51.361496197219864], [6.069305981791429, 51.42929682860019], [6.067229418269315, 51.452284250450376], [5.831383773518002, 51.72675987776683], [5.822166879169315, 51.738643203730675], [5.814186213888445, 51.75138971537396], [5.807521997399418, 51.76487128783362], [5.802241216800273, 51.77895240759242], [5.798396953224903, 51.79349153462814], [5.796027848284281, 51.80834252513982], [5.795157715650306, 51.82335610055], [5.795795301686508, 51.83838134801699], [5.797934197531712, 51.853267237374396], [5.801552903520367, 51.86786413924998], [5.806615045291998, 51.882025329104], [5.813069739417518, 51.895608462068964], [5.820852104867186, 51.908477003765896], [5.829883915179087, 51.92050160271503], [5.840074384772674, 51.931561390545724], [5.851321081503542, 51.941545196936154], [5.863510956286658, 51.95035266707063], [5.876521479438515, 51.95789527038201], [5.890221872315987, 51.964097190439595], [5.904474421871727, 51.96889608703766], [5.91913586491253, 51.97224372282416], [5.934058828146423, 51.97410644817097], [5.979879302170546, 51.97750475835714], [5.984462812088549, 51.98409328224165], [5.993786618082559, 51.995075651923486], [6.004120984316639, 52.00511291632083], [6.015370583931739, 52.014112489118595], [6.027431647720091, 52.02199135593659], [6.040192921319143, 52.02867684007557], [6.053536691450485, 52.03410727290586], [6.067339871737487, 52.03823256271469], [6.119115741737459, 52.05103341071473], [6.132539272286047, 52.05370888674557], [6.146150800446997, 52.05514959681497], [6.159836987959114, 52.055343544652416], [6.173483874899841, 52.05428911532455], [6.186977828588238, 52.05199508868219], [6.200206489763121, 52.04848056625367], [6.41016294309427, 51.982308184298155], [6.556224472987506, 52.01397309193306], [6.552977232378885, 52.02222804694074], [6.548972318472963, 52.03630586131266], [6.546358491076604, 52.050706975825996], [6.545160636637111, 52.065294276385934], [6.54539016001673, 52.0799288762063], [6.547044875906092, 52.094471438161115], [6.550109029630717, 52.10878350142384], [6.554553447152447, 52.1227287997633], [6.560335812837663, 52.13617455894479], [6.567401072347614, 52.14899276088348], [6.575681956814923, 52.161061362514296], [6.585099623315526, 52.172265457773065], [6.595564405538094, 52.18249837162584], [6.606976667503722, 52.191662675729916], [6.619227752207586, 52.1996711160564], [6.632201016150456, 52.2064474436424], [6.868144251201795, 52.31538342493494], [6.755190754223772, 52.313811495290835], [6.740115249246002, 52.31436034 ...
