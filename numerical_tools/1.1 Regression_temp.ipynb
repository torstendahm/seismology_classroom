# %% [markdown]
# # 1D Regression

# %% [markdown]
# what is done
#
# not sure what to do here in detail, if necessary at all?
# IDEAS?
#
# Others examples? where regression fit might better

# %%
import numpy as num
import matplotlib.pyplot as plt
import pandas as pd

# %%
file = 'data/hourly_data_modified.txt' 

data = pd.read_csv(file)

tempcol = 'TT_TU'
timecol = 'seconds'

numyears = 0.009
idxyear = int(24*365 * numyears)

xdata = data[timecol][:idxyear]
ydata = data[tempcol][:idxyear]

# %%
order = 10

coeff = num.polyfit(xdata, ydata, order)
print('Coeffs')
print(coeff)
print(['{0:f}'.format(c) for c in coeff])

model = num.poly1d(coeff)
yregr = model(xdata)

plt.figure()
plt.scatter(xdata, ydata, label='Data')
plt.plot(xdata, yregr, color='red', label='Regression')
plt.legend(loc='lower right')
plt.show()
# Out:
# Coeffs
# [-1.29400277e-49  1.79166421e-43 -1.04623402e-37  3.34702070e-32
#  -6.37433572e-27  7.34331727e-22 -4.95182678e-17  1.77173264e-12
#  -2.66870783e-08  1.37652422e-04  5.54259707e+00]
# ['-0.000000', '0.000000', '-0.000000', '0.000000', '-0.000000', '0.000000', '-0.000000', '0.000000', '-0.000000', '0.000138', '5.542597']

# %% [markdown]
# #
# - Determine average temperature per regression
#     control: print(num.mean(ydata))
