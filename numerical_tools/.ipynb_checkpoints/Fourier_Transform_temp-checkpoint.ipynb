# %% [markdown]
# # Fourier Transformation

# %% [markdown]
# Whats done here

# %%
import numpy as num
import matplotlib.pyplot as plt

import pandas as pd

# %%
file = 'data/NY_climate_2010.csv'

df = pd.read_csv(file)

# %%
print(df.head(10))
# Out:
#        STATION                       NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0  USW00014732  LA GUARDIA AIRPORT, NY US   40.7792     -73.88        3.4
# 1  USW00014732  LA GUARDIA AIRPORT, NY US   40.7792     -73.88        3.4
# 2  USW00014732  LA GUARDIA AIRPORT, NY US   40.7792     -73.88        3.4
# 3  USW00014732  LA GUARDIA AIRPORT, NY US   40.7792     -73.88        3.4
# 4  USW00014732  LA GUARDIA AIRPORT, NY US   40.7792     -73.88        3.4
# 5  USW00014732  LA GUARDIA AIRPORT, NY US   40.7792     -73.88        3.4
# 6  USW00014732  LA GUARDIA AIRPORT, NY US   40.7792     -73.88        3.4
# 7  USW00014732  LA GUARDIA AIRPORT, NY US   40.7792     -73.88        3.4
# 8  USW00014732  LA GUARDIA AIRPORT, NY US   40.7792     -73.88        3.4
# 9  USW00014732  LA GUARDIA AIRPORT, NY US   40.7792     -73.88        3.4
#
#              DATE  HLY-CLDH-NORMAL HLY-CLDH-NORMAL_ATTRIBUTES  \
# 0  01-01T01:00:00              0.0                          C
# 1  01-01T02:00:00              0.0                          C
# 2  01-01T03:00:00              0.0                          C
# 3  01-01T04:00:00              0.0                          C
# 4  01-01T05:00:00              0.0                          C
# 5  01-01T06:00:00              0.0                          C
# 6  01-01T07:00:00              0.0                          C
# 7  01-01T08:00:00              0.0                          C
# 8  01-01T09:00:00              0.0                          C
# 9  01-01T10:00:00           -432.0                          C
#
#    HLY-CLOD-PCTBKN HLY-CLOD-PCTBKN_ATTRIBUTES  ...  HLY-WIND-2NDPCT  \
# 0              134                          C  ...              178
# 1              155                          C  ...              197
# 2              162                          C  ...              182
# 3              149                          C  ...              164
# 4              135                          C  ...              174
# 5              133                          C  ...              182
# 6              205                          C  ...              171
# 7              238                          C  ...              165
# 8              231                          C  ...              184
# 9              249                          C  ...              169
#
#   HLY-WIND-2NDPCT_ATTRIBUTES  HLY-WIND-AVGSPD HLY-WIND-AVGSPD_ATTRIBUTES  \
# 0                          C              5.6                          C
# 1                          C              5.6                          C
# 2                          C              5.5                          C
# 3                          C              5.5                          C
# 4                          C              5.5                          C
# 5                          C              5.4                          C
# 6                          C              5.4                          C
# 7                          C              5.5                          C
# 8                          C              5.8                          C
# 9                          C              5.8                          C
#
#    HLY-WIND-PCTCLM HLY-WIND-PCTCLM_ATTRIBUTES  HLY-WIND-VCTDIR  \
# 0               24                          C              308
# 1               33                          C              309
# 2               27                          C              312
# 3               29                          C              314
# 4               31                          C              314
# 5               38                          C              312
# 6               36                          C              311
# 7               33                          C              312
# 8               29                          C              313
# 9               36                          C              314
#
#   HLY-WIND-VCTDIR_ATTRIBUTES  HLY-WIND-VCTSPD HLY-WIND-VCTSPD_ATTRIBUTES
# 0                          C              2.8                          C
# 1                          C              2.9                          C
# 2                          C              2.9                          C
# 3                          C              2.9                          C
# 4                          C              2.9                          C
# 5                          C              2.7                          C
# 6                          C              2.8                          C
# 7                          C              2.7                          C
# 8                          C              2.8                          C
# 9                          C              2.9                          C
#
# [10 rows x 58 columns]

# %%
print(df.columns)
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE',
#        'HLY-CLDH-NORMAL', 'HLY-CLDH-NORMAL_ATTRIBUTES', 'HLY-CLOD-PCTBKN',
#        'HLY-CLOD-PCTBKN_ATTRIBUTES', 'HLY-CLOD-PCTCLR',
#        'HLY-CLOD-PCTCLR_ATTRIBUTES', 'HLY-CLOD-PCTFEW',
#        'HLY-CLOD-PCTFEW_ATTRIBUTES', 'HLY-CLOD-PCTOVC',
#        'HLY-CLOD-PCTOVC_ATTRIBUTES', 'HLY-CLOD-PCTSCT',
#        'HLY-CLOD-PCTSCT_ATTRIBUTES', 'HLY-DEWP-10PCTL',
#        'HLY-DEWP-10PCTL_ATTRIBUTES', 'HLY-DEWP-90PCTL',
#        'HLY-DEWP-90PCTL_ATTRIBUTES', 'HLY-DEWP-NORMAL',
#        'HLY-DEWP-NORMAL_ATTRIBUTES', 'HLY-HIDX-NORMAL',
#        'HLY-HIDX-NORMAL_ATTRIBUTES', 'HLY-HTDH-NORMAL',
#        'HLY-HTDH-NORMAL_ATTRIBUTES', 'HLY-PRES-10PCTL',
#        'HLY-PRES-10PCTL_ATTRIBUTES', 'HLY-PRES-90PCTL',
#        'HLY-PRES-90PCTL_ATTRIBUTES', 'HLY-PRES-NORMAL',
#        'HLY-PRES-NORMAL_ATTRIBUTES', 'HLY-TEMP-10PCTL',
#        'HLY-TEMP-10PCTL_ATTRIBUTES', 'HLY-TEMP-90PCTL',
#        'HLY-TEMP-90PCTL_ATTRIBUTES', 'HLY-TEMP-NORMAL',
#        'HLY-TEMP-NORMAL_ATTRIBUTES', 'HLY-WCHL-NORMAL',
#        'HLY-WCHL-NORMAL_ATTRIBUTES', 'HLY-WIND-1STDIR',
#        'HLY-WIND-1STDIR_ATTRIBUTES', 'HLY-WIND-1STPCT',
#        'HLY-WIND-1STPCT_ATTRIBUTES', 'HLY-WIND-2NDDIR',
#        'HLY-WIND-2NDDIR_ATTRIBUTES', 'HLY-WIND-2NDPCT',
#        'HLY-WIND-2NDPCT_ATTRIBUTES', 'HLY-WIND-AVGSPD',
#        'HLY-WIND-AVGSPD_ATTRIBUTES', 'HLY-WIND-PCTCLM',
#        'HLY-WIND-PCTCLM_ATTRIBUTES', 'HLY-WIND-VCTDIR',
#        'HLY-WIND-VCTDIR_ATTRIBUTES', 'HLY-WIND-VCTSPD',
#        'HLY-WIND-VCTSPD_ATTRIBUTES'],
#       dtype='object')

# %%
df['year'] = 2010
df['month'] = df['DATE'].str.slice(0, 2)
df['day'] = df['DATE'].str.slice(3, 5)
#print(df[['day', 'month']])

df['minute'] = df['DATE'].str.slice(6, 8).astype(float) * 60
print(df['minute'])

df['datetime'] = pd.to_datetime(df[['year', 'month', 'day', 'minute']])
print(df['datetime'])
# Out:
# 0          60.0
# 1         120.0
# 2         180.0
# 3         240.0
# 4         300.0
#           ...
# 26272    1140.0
# 26273    1200.0
# 26274    1260.0
# 26275    1320.0
# 26276    1380.0
# Name: minute, Length: 26277, dtype: float64
# 0       2010-01-01 01:00:00
# 1       2010-01-01 02:00:00
# 2       2010-01-01 03:00:00
# 3       2010-01-01 04:00:00
# 4       2010-01-01 05:00:00
#                 ...
# 26272   2010-12-31 19:00:00
# 26273   2010-12-31 20:00:00
# 26274   2010-12-31 21:00:00
# 26275   2010-12-31 22:00:00
# 26276   2010-12-31 23:00:00
# Name: datetime, Length: 26277, dtype: datetime64[ns]

# %%
plt.figure()
plt.plot(df['datetime'], df['HLY-TEMP-NORMAL'])
plt.xlabel('Date')
plt.ylabel('Temperature in C')
plt.show()

# %%
plt.figure()
plt.plot(df['datetime'][:2000], df['HLY-TEMP-NORMAL'][:2000])
plt.xlabel('Date')
plt.ylabel('Temperature in C')
plt.show()

# %% [markdown]
# ## FFT
# Fast
# Discrete etc.

# %%
sp = num.fft.rfft(df['HLY-TEMP-NORMAL'])
freq = num.fft.rfftfreq(len(df['HLY-TEMP-NORMAL']))

plt.figure()
plt.loglog(freq, abs(sp))

plt.show()
