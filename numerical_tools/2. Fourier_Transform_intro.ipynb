# %% [markdown]
# # Fourier Transformation

# %% [markdown]
# Whats done here
#
# Amplitude and phase spectrum

# %%
import numpy as num
import scipy as sp
import matplotlib.pyplot as plt

# %%
df = 100  # Abstastfrequenz [Hz]
timelen = 10  # Länger der Zeitspur [s]
dt = 1 / df  # Abtastintervall [s]

numsamples = timelen * df
x = num.arange(numsamples) / df

# %%
sin1 = 1.
ysignal = num.sin(2 * num.pi * sin1 * x)

amps = abs(num.fft.rfft(ysignal)) * dt
freqs = num.fft.rfftfreq(numsamples, d=dt)

plt.figure(figsize=(16, 9))
ax = plt.subplot(2, 1, 1)
ax.plot(x, ysignal)
ax = plt.subplot(2, 1, 2)
ax.plot(freqs, amps)
# ax.loglog(freqs, amps)

plt.show()

# %%
sin1 = 10.
ysignal = num.sin(2 * num.pi * sin1 * x)

amps = abs(num.fft.rfft(ysignal)) * dt
freqs = num.fft.rfftfreq(numsamples, d=dt)

plt.figure(figsize=(16, 9))
ax = plt.subplot(2, 1, 1)
ax.plot(x, ysignal)
ax = plt.subplot(2, 1, 2)
ax.plot(freqs, amps)
# ax.loglog(freqs, amps)

plt.show()

# %%
sin1 = 1.
sin2 = 10.
ysignal = num.sin(2 * num.pi * sin1 * x) + num.sin(2 * num.pi * sin2 * x)

amps = abs(num.fft.rfft(ysignal)) * dt
freqs = num.fft.rfftfreq(numsamples, d=dt)

plt.figure(figsize=(16, 9))
ax = plt.subplot(2, 1, 1)
ax.plot(x, ysignal)
ax = plt.subplot(2, 1, 2)
# ax.plot(freqs, amps)
ax.loglog(freqs, amps)

plt.show()

# %%
sin1 = 1.
cos1 = 10.
ysignal = num.sin(2 * num.pi * sin1 * x) + num.cos(2 * num.pi * cos1 * x)

amps = abs(num.fft.rfft(ysignal)) * dt
freqs = num.fft.rfftfreq(numsamples, d=dt)

plt.figure(figsize=(16, 9))
ax = plt.subplot(2, 1, 1)
ax.plot(x, ysignal)
ax = plt.subplot(2, 1, 2)
# ax.plot(freqs, amps)
ax.loglog(freqs, amps)

plt.show()

# %%
ysignal = num.zeros(numsamples)

## single peak
#ysignal[99] = 0.5
ysignal[100] = 1
#ysignal[101] = 0.5

## box
ysignal[100:200] = 1

amps = abs(num.fft.rfft(ysignal)) * dt
freqs = num.fft.rfftfreq(numsamples, d=dt)

plt.figure(figsize=(16, 9))
ax = plt.subplot(2, 1, 1)
ax.plot(x, ysignal)
ax = plt.subplot(2, 1, 2)
ax.plot(freqs, amps)
#ax.loglog(freqs, amps)

plt.show()

# %%
frequencies = num.linspace(1, 100, 100)
# print(frequencies)

ysignal = num.zeros(numsamples)
for ff in frequencies:
    ysignal += (1/ff) * num.sin(2 * num.pi * ff * x)
    #ysignal += ff * num.sin(2 * num.pi * ff * x)

amps = abs(num.fft.rfft(ysignal)) * dt
freqs = num.fft.rfftfreq(numsamples, d=dt)

plt.figure(figsize=(16, 9))
ax = plt.subplot(2, 1, 1)
ax.plot(x, ysignal)
ax = plt.subplot(2, 1, 2)
ax.plot(freqs, amps)
# ax.loglog(freqs, amps)

plt.show()
