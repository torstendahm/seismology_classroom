# %% [markdown]
# # Module 3 - Introduction to common seismological toolboxes
#
# Different toolboxes aid in handling, processing and investigation of seismological data as, e.g.:
# * *Obspy* ([docs.obspy.org](https://docs.obspy.org/))
# * *Pyrocko* ([pyrocko.org](https://pyrocko.org/))
# * *Integrated Seismic Program* ISP ([integratedseismicprogram.com](https://integratedseismicprogram.com/))
# * *SeisComP* ([seiscomp.de](https://www.seiscomp.de/doc/index.html) - full version costs money)
# * ...
#
# All of them have their own strengths and weaknesses, so it is fully worth to check out each of them and also search for other tool boxes.
#
# Here we will focus on *Pyrocko* and *Obspy* as two well known and often used free software packages. They are designed for usage in scripts. So we will do the same.
#
# This module shows to load and process
# * Station data (especially StationXML)
# * Event data (QuakeML)
# * Waveform data (miniSEED)
#
# in *Pyrocko* and *Obspy*.

# %% [markdown]
# ## 1. Installation of *Obspy* and *Pyrocko*
#
# For installation instructions it is always smart to check the instructions on the [obspy website](https://docs.obspy.org/) or [pyrocko website](https://pyrocko.org/). They will help you.

# %% [markdown]
# - [X] Translation Obspy <-> Pyrocko
# 2. Intro to (provided data)
#     1. station data handling
#         - [X] StationXML
#         - [X] Pyrocko Station format
#         - [X] Pyrocko Response
#         - [X] Obspy Station format (?)
#         - [X] Obspy Response
#     2. event data handling
#         - [X] QuakeML
#         - [ ] Pyrocko event format
#         - [ ] Obspy event format
#     3. waveform data handling
#         - [X] MiniSEED (a lot more)
#         - [X] Pyrocko - reading (trace snuffle)
#         - [X] Pyrocko - squirrel (squirrel snuffle)
#         - [X] Obspy stream (obspy plot)

# %% [markdown]
# ## 2. Waveform data handling
#
# A common waveform format used in seismology is `miniSEED` ([iris](https://ds.iris.edu/ds/nodes/dmc/data/formats/miniseed/)). It is optimized for seismic data and ships not only the data, but also the respective network, station and channel the data was recorded on. This section explains, how miniSEED data is loaded and inspected.
#
#
# Note: There are much more common and uncommon data formats (check e.g. [here for a more complete view on the zoo of seismic waveform formats](https://pyrocko.org/docs/current/_modules/pyrocko/io.html#load)). We will focus on miniSEED though as the most common one.
#
#
# ### *Obspy*
#
# Let's load a waveform file with *Obspy* (follows the [tutorial](https://docs.obspy.org/tutorial/code_snippets/reading_seismograms.html#accessing-waveform-data))

# %%
# Let's start with obspy
from obspy import read

# This is an obspy stream
st = read('data/data_GE.KTHA..HHZ_2020-10-30_11-30-26.mseed')

# %% [markdown]
# The loaded stream contains the loaded waveform as traces. Meta data can be seen with different techniques:

# %%
# The stream stats
print(st)

# Let's check, how many traces are loaded
print('{} traces have been loaded into the stream'.format(len(st)))
# Out:
# 1 Trace(s) in Stream:
# GE.KTHA..HHZ | 2020-10-30T11:30:26.980000Z - 2020-10-30T12:30:26.970000Z | 100.0 Hz, 360000 samples
# 1 traces have been loaded into the stream

# %%
# Accessing an individual trace (here the first) of the stream
tr = st[0].copy()

# Print the trace stats
print(tr.stats)
# Out:
#          network: GE
#          station: KTHA
#         location:
#          channel: HHZ
#        starttime: 2020-10-30T11:30:26.980000Z
#          endtime: 2020-10-30T12:30:26.970000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 360000
#            calib: 1.0
#          _format: MSEED
#            mseed: AttribDict({'dataquality': 'D', 'number_of_records': 118, 'encoding': 'STEIM1', 'byteorder': '>', 'record_length': 4096, 'filesize': 483328})

# %%
# Plot of the loaded data
st.plot();

# %% [markdown]
# ### *Pyrocko*
#
# *Pyrocko* ships different techniques to load and to display data from simple waveform file reading to a scan of directories using `pile` and `squirrel`.

# %%
# Let's start with pyrocko
from pyrocko.io import load
from pyrocko.pile import make_pile
from pyrocko.squirrel import Squirrel

# This is a list of traces
traces = load(filename='data/data_GE.KTHA..HHZ_2020-10-30_11-30-26.mseed')

# OR This generates a pile
p = make_pile('data/data_GE.KTHA..HHZ_2020-10-30_11-30-26.mseed')

# OR this generates a squirrel
sq = Squirrel()
sq.add('data/data_GE.KTHA..HHZ_2020-10-30_11-30-26.mseed')
# Out:
# selecting files... done. 1 file selected.
# Looking at files [----------------------------------------] 100% Time:  0:00:00
# Scanning files [------------------------------------------] 100% Time:  0:00:00
# D◷ Gathering file names    working           MD◷ Preparing database      working           MD◷ Indexing files          working           MD◷ Aggregating selection   working           M

# %% [markdown]
# `traces` contains the loaded waveform as a list of individual traces. Meta data can be seen here using:

# %%
# Let's check, how many traces are loaded
print('{} trace has been loaded into the traces list'.format(len(traces)))  # Trace list
print('{} trace has been loaded into the pile'.format(len(p.all())))  # Pile
print('{} trace has been loaded into the squirrel'.format(len(sq.get_waveforms())))  # Squirrel

# Accessing an individual trace (here the first) from the trace list
tr = traces[0].copy()
print(tr)

# OR accessing an individual trace (here the first) from the pile
tr = p.all()[0]
print(tr)

# OR accessing an individual trace (here the first) from the squirrel
tr = sq.get_waveforms()[0]
print(tr)
# Out:
# 1 trace has been loaded into the traces list
# 1 trace has been loaded into the pile
# 1 trace has been loaded into the squirrel
# Trace (GE, KTHA, , HHZ)
#   timerange: 2020-10-30 11:30:26.98 - 2020-10-30 12:30:26.97
#   delta t: 0.01
#   last: True
#   offset_end: 0
#   offset_start: 0
#   segment_size: 0
#
# Trace (GE, KTHA, , HHZ)
#   timerange: 2020-10-30 11:30:26.98 - 2020-10-30 12:30:26.96
#   delta t: 0.01
#
# Trace (GE, KTHA, , HHZ)
#   timerange: 2020-10-30 11:30:26.98 - 2020-10-30 12:30:26.97
#   delta t: 0.01
#   last: True
#   offset_end: 0
#   offset_start: 0
#   segment_size: 1048576

# %% [markdown]
# *Pyrocko* offers a waveform viewer and real time processing tool, the Snuffler (more later). Here we will just have a look at the waveforms ([further information here](https://pyrocko.org/docs/current/apps/snuffler/manual.html)).

# %%
# Plot of the loaded data using the trace list
from pyrocko.trace import snuffle

snuffle(traces);

# OR plot of the loaded data using the pile
p.snuffle();

# OR plot of the loaded data using the squirrel
sq.snuffle();
# Out:
# cc.py:pyrocko.gui.snuffling.okada - WARNING  -
#  /home/malde/.snufflings/okada/libokada.so: undefined symbol: okada_get_consts
# --> run 'make' in okada snuffling directory <--
# cc.py:pyrocko.gui.snuffling.okada - WARNING  -
#  /home/malde/.snufflings/okada/libokada.so: undefined symbol: okada_get_consts
# --> run 'make' in okada snuffling directory <--
# cc.py:pyrocko.gui.snuffling.okada - WARNING  -
#  /home/malde/.snufflings/okada/libokada.so: undefined symbol: okada_get_consts
# --> run 'make' in okada snuffling directory <--

# %% [markdown]
# ## 3. Station meta data handling
#
# Station meta data contains all information on seismic networks, their stations and associated channels, recording times, instrument responses and much more. This might be important for further processing and is not included in the miniSEED files.
#
# The most common format for station information is the [`StationXML`](http://docs.fdsn.org/projects/stationxml/en/latest/#). Here we will see, how these files can be loaded and used within *Obspy* and *Pyrocko*.
#
# ### *Obspy*

# %%
# import loading function
from obspy import read_inventory

# Stations are loaded into an inventory
inv = read_inventory('data/stations.xml')

# Plot the location of the stations.
inv.plot();

# Extract station information
for net in inv.networks:
    for s in net:
        print('{}.{:<4}: lat [deg] {:.4f}, lon [deg] {:.4f}'.format(net.code, s.code, s.latitude, s.longitude))
# Out:
# GE.KARP: lat [deg] 35.5471, lon [deg] 27.1611
# GE.KTHA: lat [deg] 36.2566, lon [deg] 23.0621
# GE.ZKR : lat [deg] 35.1147, lon [deg] 26.2169

# %% [markdown]
# But what can we use the station information for? Perhaps **restitution**, so the removal of the instrument response from our raw traces:

# %%
# Choosing an individual trace (here the first) of the stream
tr = st[0].copy()
print(tr.max())

# Removing the response and extract trace in displacement
tr.remove_response(inventory=inv, output='DISP', pre_filt=[0.001, 0.01, 10., 20.])

# Plot the ground displacement
tr.plot();
# Out:
# -5730988

# %% [markdown]
# ### *Pyrocko*

# %%
# Import of the loading function
from pyrocko.io import stationxml

# Stations are loaded into Pyrocko StationXML 
sx = stationxml.load_xml(filename='data/stations.xml')

# Convert stations into Pyrocko format and print the station name
stations = sx.get_pyrocko_stations()

for s in stations:
    print('{}.{:<4}: lat [deg] {:.4f}, lon [deg] {:.4f}'.format(s.network, s.station, s.lat, s.lon))
    
# OR one uses the Squirrel
sq.add('data/stations.xml');
# Out:
# D◷ Gathering file names    working           MD◷ Preparing database      working           MD◷ Indexing files          working           MD◷ Aggregating selection   working           M
# GE.KARP: lat [deg] 35.5471, lon [deg] 27.1611
# GE.KTHA: lat [deg] 36.2566, lon [deg] 23.0621
# GE.ZKR : lat [deg] 35.1147, lon [deg] 26.2169

# %% [markdown]
# Lets now perform the **restitution** also with *Pyrocko*, so the removal of the instrument response from our raw traces:

# %%
# Choosing an individual trace (here the first) of the traces list
tr = traces[0].copy()

# Removing the response and extract trace in displacement
resp = sx.get_pyrocko_response(
    nslc=tr.nslc_id,  # Extract the response matching with the trace network-station-location-channel id
    fake_input_units='M')  # Get response to extract displacement signal (in [m])

tr = tr.transfer(
    0.,  # Rise time of the taper
    transfer_function=resp,
    freqlimits=(0.001, 0.01, 10., 20.),
    invert=True,
    demean=True)

# Plot the ground displacement
snuffle([tr]);
# Out:
# cc.py:pyrocko.io.stationxml     - WARNING  - GE.KTHA..HHZ, stage 1: PZ normalization frequency (1) is different from stage gain frequency (0.02) -> Emulating possibly incorrect evalresp behaviour. Correction factor: 1.01471
# cc.py:pyrocko.io.stationxml     - WARNING  - GE.KTHA..HHZ: Instrument sensitivity value inconsistent with sensitivity computed from complete response
#   reported value: 5.88e+08
#   computed value: 5.96649e+08
#   at frequency [Hz]: 0.02
#   factor: 1.01471
#   difference [dB]: 0.126831
#   limit [dB]: 0.1
# cc.py:pyrocko.gui.snuffling.okada - WARNING  -
#  /home/malde/.snufflings/okada/libokada.so: undefined symbol: okada_get_consts
# --> run 'make' in okada snuffling directory <--

# %% [markdown]
# The **response** and trace can also be extracted from the Squirrel instead (following the [example](https://pyrocko.org/docs/current/library/examples/squirrel/cli_tool.html)):

# %%
# Choosing an individual trace (here the first) of the traces list extracted from squirrel
traces_squirrel = sq.get_waveforms(codes=[('GE', 'KTHA', '', 'HHZ')])
tr = traces_squirrel[0].copy()

# Removing the response and extract trace in displacement
resp = sq.get_response(tr).get_effective(
    input_quantity='displacement')  # Get response to get 'displacement' signal

tr = tr.transfer(
    0.,  # Rise time of the taper
    transfer_function=resp,
    freqlimits=(0.001, 0.01, 10., 20.),
    invert=True,
    demean=True)

# Plot the ground displacement
snuffle([tr]);
# Out:
# cc.py:pyrocko.gui.snuffling.okada - WARNING  -
#  /home/malde/.snufflings/okada/libokada.so: undefined symbol: okada_get_consts
# --> run 'make' in okada snuffling directory <--

# %% [markdown]
# ## 4. Event data handling
#
# Earthquakes are often referred to as `events`. Event data as location, depth, time and mechanism (the style of faulting) is published for large earthquakes e.g. by [USGS](https://earthquake.usgs.gov/earthquakes/search/), [Global CMT](https://www.globalcmt.org/CMTsearch.html) or [GEOFON](https://geofon.gfz-potsdam.de/eqinfo/list.php). The most common data format for event information is [QuakeML](https://quake.ethz.ch/quakeml). Here we present, how QuakeML is loaded in *Obspy* and *Pyrocko*.
#
# ### *Obspy*

# %%
# Import of the event loading function
from obspy import read_events

# Loading of a QuakeML
catalog = read_events('data/quakeml.xml')

# Plot the event location
catalog.plot();

# %% [markdown]
# ### *Pyrocko*

# %%
# Import of the event loading function
from pyrocko.io.quakeml import QuakeML

# Loading of a QuakeML
qml = QuakeML.load_xml(filename='data/quakeml.xml')

# Convert QuakeML to Pyrocko event
events = qml.get_pyrocko_events()

# Check the event time compared to the recorded trace in Snuffler
snuffle(traces, events=events)
# Out:
# cc.py:pyrocko.io.quakeml        - WARNING  - Event quakeml:us.anss.org/event/7000c7y0: No preferred origin set, more than one available, using first
# cc.py:pyrocko.gui.snuffling.okada - WARNING  -
#  /home/malde/.snufflings/okada/libokada.so: undefined symbol: okada_get_consts
# --> run 'make' in okada snuffling directory <--

# %% [markdown]
# Or again use the Squirrel:

# %%
# Loading of a QuakeML
sq.add('data/quakeml.xml')

# Check the event time compared to the recorded trace in Snuffler
sq.snuffle()
# Out:
# D◷ Gathering file names    working           MD◷ Preparing database      working           MD◷ Indexing files          working           cc.py:psq.io                    - ERROR    - Cannot read file: /home/malde/src/seiscl/seistools/data/quakeml.xml
# MD◷ Aggregating selection   working           Mcc.py:pyrocko.gui.snuffling.okada - WARNING  -
#  /home/malde/.snufflings/okada/libokada.so: undefined symbol: okada_get_consts
# --> run 'make' in okada snuffling directory <--

# %% [markdown]
# ## 5. Compatibility - *Obspy* and *Pyrocko* talk with each other
#
# From time to time you might be faced with the problem of converting an *Obspy* stream into *Pyrocko* traces to watch it in snuffler etc.. To do so easily, *Pyrocko* contains a compatibility module [`obspy_compat`](https://pyrocko.org/docs/current/library/reference/obspy_compat.html):

# %%
# Import of the compatibility module
from pyrocko import obspy_compat

# Start compatiblity mode
obspy_compat.plant()

# Now snuffle the obspy stream 
st.snuffle();

# Or convert it to pyrocko traces:
traces_converted = st.to_pyrocko_traces()
